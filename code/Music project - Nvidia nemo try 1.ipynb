# %%
# !pip install transformers==4.19.0 --quiet
# # install necessary packages
# !pip install datasets==2.0 --quiet
# !pip install openprompt --quiet
# !pip install torch --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.4/146.4 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.3 MB/s eta 0:00:00

# %%
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer

transformers.__version__
# Out:
# '4.19.0'

# %%
# model_name = "stabilityai/stablecode-instruct-alpha-3b"
model_name = "nvidia/nemo-megatron-gpt-1.3B"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
  model_name,
  trust_remote_code=True,
  torch_dtype="auto",
)
model.cuda()
# Out:
# ---------------------------------------------------------------------------
# EntryNotFoundError                        Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     600             # Load from URL or cache if already cached
# --> 601             resolved_config_file = cached_path(
#     602                 config_file,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     281         # URL, so get it from the cache (downloading if necessary)
# --> 282         output_path = get_from_cache(
#     283             url_or_filename,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     485             r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
# --> 486             _raise_for_status(r)
#     487             etag = r.headers.get("X-Linked-Etag") or r.headers.get("ETag")
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in _raise_for_status(request)
#     408         elif error_code == "EntryNotFound":
# --> 409             raise EntryNotFoundError(f"404 Client Error: Entry Not Found for url: {request.url}")
#     410         elif error_code == "RevisionNotFound":
#
# EntryNotFoundError: 404 Client Error: Entry Not Found for url: https://huggingface.co/nvidia/nemo-megatron-gpt-1.3B/resolve/main/config.json
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-8f1d0fe50fbd> in <cell line: 4>()
#       2 model_name = "nvidia/nemo-megatron-gpt-1.3B"
#       3
# ----> 4 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       5 model = AutoModelForCausalLM.from_pretrained(
#       6   model_name,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     509         if config_tokenizer_class is None:
#     510             if not isinstance(config, PretrainedConfig):
# --> 511                 config = AutoConfig.from_pretrained(
#     512                     pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     513                 )
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     678         kwargs["name_or_path"] = pretrained_model_name_or_path
#     679         trust_remote_code = kwargs.pop("trust_remote_code", False)
# --> 680         config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     681         if "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]:
#     682             if not trust_remote_code:
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     551         original_kwargs = copy.deepcopy(kwargs)
#     552         # Get config dict associated with the base config file
# --> 553         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     554
#     555         # That config file may point us toward another config file to use.
#
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     624             )
#     625         except EntryNotFoundError:
# --> 626             raise EnvironmentError(
#     627                 f"{pretrained_model_name_or_path} does not appear to have a file named {configuration_file}."
#     628             )
#
# OSError: nvidia/nemo-megatron-gpt-1.3B does not appear to have a file named config.json.
